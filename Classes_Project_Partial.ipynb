# %%
#Greet the user
print('Welcome to Alberta Hospital (AH) Managment system')
 #1 Doctor Class
class Doctor:
  def __init__(self, ):
    pass
  def formatDrinfo():
  # Formats each Dr's info (Properties) in the same format used in the
  # .txt file (i.e. has underscores  between values)
    pass

  def enterDrinfo():
  # Asks the user to enter Dr properties (listed in the properties point)
    pass

  def readDrinfo():
  # Reads from doctors.txt file and fills the Dr object in a list
    pass

  def searchDrByld():
  #  # Searches whether the Dr is in the list of Dr's in the list using
  # the ID entered
    pass

  def searchDrByName():
  # Searches whether the Dr is in the list of Dr's in the list using
  # the name entered
    pass

  def displayDrInfo():
  # Displays Dr info on diffrent lines as a list
    pass

  def editDrInfo():
  # Asks the user to enter the ID of the Doctor to change their info,
  # and then the user can enter the new Dr Info 
    pass

  def displayDrList():
  # Displays all the doctors info read from the file as a report/table
    pass

  def writeListofDrtoFile():
  # Writes the list of Dr's to the doctors.txt file after
  # formatting correctly
    pass

  def addDrtoFile():
  # Writes Dr's to the doctors.txt file after formating correctly 
    pass

#---------------------------------------------------------------#
#2 Facility Class
class Facility:
  def __init__(self,):
    pass
  def addFacility():
  # Adds and writes the facility name to the file
    pass

  def displayFacilities():
  # Displays the list of facilities
    pass

  def writeListofFacilitiestoFile():
  # Writes the faciloities list to the facilities.txt file
    pass

#---------------------------------------------------------------#
#3 Labratory Class
class Labratory:
  def __init__(self, ):
    pass
  def addLabtoFile():
  # Adds and Writes the lab name to the file in the format 
  # of the data that is in the file
    pass

  def writeListofLabstoFile():
  # Writes the list of labs into the file laboratories.txt
    pass

  def displayLabsList():
  # Displays the list of Laboratories
    pass

  def formatDrInfo():
  # Formats the laboraty object similar to the laboratories.txt file
    pass

  def enterLabInfo():
  # Asks the user to enter the lab name, cost and forms a Laboraty object
    pass

  def readLabFile():
  # Reads the laboratories.txt file and fills it's contents in a list
  # of labotatory objets
    pass

#---------------------------------------------------------------#
#4 Patient Class
class Patient:
  def __init__(self, ):
    pass
  def fromatPinfo():
  # Formats the patients info to be added to the file
    pass

  def enterPinfo():
  # Asks the user to enter the apatient info
    pass

  def readPfile():
  # Reads the Patient.txt files
    pass

  def searchPbyld():
  # Searches for a patient using their ID
    pass

  def displayPinfo():
  # Displays patients info
    pass

  def editPinfo():
  # Asks the user to edit patient info
    pass

  def displayPlist():
  # Displays the list of patients
    pass

  def writeListofPtoFile():
  # Writes a list of patients into the patients.txt file
    pass

  def addPtoFile():
  # Adds new Patient to file
    pass

#---------------------------------------------------------------#
#5 Managment Class
class Managment:
  def __init__(self, ):
    pass

#------------------------------------------------------------------------------
"""First:
    The doctor menu while loop,
   Second:
    Work through each menu item,
1  -  The doctors list, by accessing the doctors.txt file and displaying it,
2  -  Then the search for doctor by ID
3  -  Then the serach for doctor by Name
4  -  Then Add a doctor (Which we didn't cover in class)
5  -  Then editing the doctor file (Again have no idea how to do that)
6  -  How to exit the loop

"""
#Doctor Menu
Doctor = int(input('Doctors Menu:'))
for x in range(Doctor):
  print('1 - Display Doctors List\n', '2 - Search for Doctor by ID number\n', '3 - Search for Doctor by Name\n', '4 - Add a Doctor', '5 - Edit a Doctors info', '6 - Back to the main menu\n')
# Out:
# Welcome to Alberta Hospital (AH) Managment system
# Doctors Menu:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-05d493c98234> in <module>
#     160 #Doctor Menu
#     161 Doctor = print('Doctors Menu:')
# --> 162 for x in range(Doctor):
#     163   print('1 - Display Doctors List\n', '2 - Search for Doctor by ID number\n', '3 - Search for Doctor by Name\n', '4 - Add a Doctor', '5 - Edit a Doctors info', '6 - Back to the main menu\n')
#
# TypeError: 'NoneType' object cannot be interpreted as an integer
